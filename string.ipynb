# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4508-hub/python-programmes/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# strings in python
a = input()
b=a.split()
print(b)
c=" ".join(b)
print(c)
# Out:
# thank you
# ['thank', 'you']
# thank you

# %%
#strings methods in python
a = "hello india"
b=a.split()
print(b)
c = " ".join(b)
print(c)
print(a.upper())
A = "vara"
print(A.upper())
B = "PAVANI"
print(B.lower())
print(B.count("A"))
print(len(A))
print(A.find("r"))
H = " bahubali epic "
print(H)
print(H.strip())
# Out:
# ['hello', 'india']
# hello india
# HELLO INDIA
# VARA
# pavani
# 2
# 4
# 2
#  bahubali epic
# bahubali epic

# %%
#count number of vowels in a given string
s = input()
vowels = "aeiouAEIOU"
count = 0
for i in s:
  if i in vowels:
    count+=1
print(count)
# Out:
# prabhas
# 2

# %%
#program that checks sub string is present in the given string,if present print
s = input()
subs = input()
if subs in s:
  print(s.find(subs))
else:
  print("no")
# Out:
# prabhas
# ajay
# no

# %%
#print reverse of the given number
def reverse(n):
  rev = 0
  while(n!=0):
    rem = n%10
    rev = rev*10 + rem
    n = n//10
  return rev
print(reverse(457))
# Out:
# 754
