# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4508-hub/python-programmes/blob/main/exercise6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tuples
#operators
t1 = tuple(input().split())
t2 = tuple(input().split())
t3 = (2,3,4,4,4)
print(t1+t2)
print(t1*3)
print(len(t2))
for i in t1:
  print(i)
if 4 in t3:
  print("hooo")
# Out:
# 77 88 99 44 66
# 78 65 43 32 21 67
# ('77', '88', '99', '44', '66', '78', '65', '43', '32', '21', '67')
# ('77', '88', '99', '44', '66', '77', '88', '99', '44', '66', '77', '88', '99', '44', '66')
# 6
# 77
# 88
# 99
# 44
# 66
# hooo

# %%
# methods
print(t1[4])
print(t3.count(4))
print(t3.index(3))
# Out:
# 66
# 1
# 1

# %%
#functions in tuple
print(len(t3))
print(max(t1))
print(min(t1))
print(sum(t3))
# Out:
# 3
# 99
# 44
# 9

# %%
#write a program to create tuples (name,age,address,college) for at least two members and concatenate the tuplrs and print the concatenated tuples
std_1= ("vara",17,"bhimavaram","vitb")
std_2 = ("pavani",14,"bhimavarm","sasi")
print(std_1+std_2)
# Out:
# ('vara', 17, 'bhimavaram', 'vitb', 'pavani', 14, 'bhimavarm', 'sasi')

# %%
#user defined tuple
t1 = tuple(map(int,input().split()))
print(t1)
# Out:
# 3 4 5 6 7 8
# (3, 4, 5, 6, 7, 8)

# %%
#zip function
t1 = (1,2,3,4,5,6)
t2 = (7,8,9,0,11,33)
print(tuple(zip(t1,t2)))
# Out:
# ((1, 7), (2, 8), (3, 9), (4, 0), (5, 11), (6, 33))

# %%
#count no.of vowels in astring no control flow allowed
s = input()
s2 = s.lower()
vowels_count = s2.count("a")+ s2.count("e")+ s2.count("i")+ s2.count("o")+ s2.count("u")
print(vowels_count)
# Out:
# vara
# 2
