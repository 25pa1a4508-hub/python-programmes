# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4508-hub/python-programmes/blob/main/exercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program that print reverse of a string
def reverse(s):
  return s[::-1]
print(reverse("india"))
# Out:
# aidni

# %%
#without using indexing and function
def reverse(str):
  for i in range(len(str)):
    print(str[len(str)-i-1],end="")
reverse("india")
# Out:
# aidni

# %%
#example code on default arguments
def print_msg(name,branch="AI&DS"):
  print("the name is",name,"the bramch is",branch)
print_msg("vara")
# Out:
# the name is vara the bramch is AI&DS

# %%
#example code on keyword arguments
def subtraction(a,b,c):
  print("the values are",a,b,c)
  return a-b-c
res = (subtraction(a=3,c=9,b=4))
print(res)
# Out:
# the values are 3 4 9
# -10

# %%
#functions that return multiple return values
def multiple_functions(*nums):
  s=sum(nums)
  c=len(nums)
  avg = s//c
  return s,c,avg
res_sum,res_count,res_avg=multiple_functions(1,2,3,4,5,7,8)
print(f"the sum is {res_sum}")
print(f"the count is {res_count}")
print(f"the average is {res_avg}")
# Out:
# the sum is 30
# the count is 7
# the average is 4

# %%
n = int(input("enter a number:"))
if n>999 and n<=9999:
        rem = n%100
        p=rem
        n = n//100
print(p)
print(n)
# Out:
# enter a number:4567
# 67
# 45
