# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4508-hub/python-programmes/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
#arthmetic operators
a = int(input("enter a number:"))
b = int(input("enter another number:"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# enter a number:5
# enter another number:6
# 11
# -1
# 30
# 0.8333333333333334
# 5
# 0
# 15625

# %%
#comparison operators
a = int(input("enter a number:"))
b = int(input("enter another number:"))
print(a==b)
print(a>=b)
print(a<=b)
print(a>b)
print(a<b)
print(a!=b)
# Out:
# enter a number:5
# enter another number:3
# False
# True
# False
# True
# False
# True

# %%
#logical operators
a = int(input("enter a number:"))
b = int(input("enter another number:"))
print(a>b and b>a)
print(a==b or b>=a)
print(not(a>b))
# Out:
# enter a number:30
# enter another number:2
# False
# False
# False
